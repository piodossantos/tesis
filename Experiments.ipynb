# %%
# !wget https://www.mediafire.com/file_premium/rjpdercd7kgfykx/Archivo.zip/file

# %%
# import zipfile

# # Ruta del archivo ZIP
# zip_file_path = '/content/file'

# # Ruta donde quieres extraer los archivos
# extract_to_path = '/content/'

# # Descomprimir el archivo
# with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_to_path)

# print("Archivos extraídos con éxito.")

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# import zipfile

# # Ruta del archivo ZIP
# zip_file_path = '/content/tesis-main.zip'

# # Ruta donde quieres extraer los archivos
# extract_to_path = '/content/'

# # Descomprimir el archivo
# with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_to_path)

# print("Archivos extraídos con éxito.")

# %%
#!wget https://www.mediafire.com/file_premium/etiia8akvx73qza/data.zip/

# %%
import sys
sys.path.append('/content/')

# from dotenv import load_dotenv

# load_dotenv()

# %%
# import drive as drive_downloader
# drive_downloader.download_files('14_UUqgoWDPPNwXvdFjDoJomHTu5l85l6')

# %% [markdown]
# * Carga el video utilizando cv2.VideoCapture.
# * Extrae los frames del video uno por uno.
# * Preprocesa cada frame para que sean compatibles con el modelo de PyTorch (tamaño, normalización, etc.).
# * Usa un modelo preentrenado de PyTorch (como ResNet) para extraer características de cada frame.
# * Aplica un algoritmo de clustering (como K-Means) a las características extraídas.
# * Asigna cada frame al cluster correspondiente.
# * Visualiza los resultados mostrando los frames y su cluster correspondiente.

# %%
# !pip install wandb

# %%
#!wget https://www.mediafire.com/file/4h0w0ulea622av9/siameseResnet18Cosine.pt

# %%
import torch
from sklearn.cluster import AgglomerativeClustering
import warnings
from preprocessing.transforms import BASELINE
from clustering.metrics import eval_massive_cluster
from experiment_framework import experiment
from validation import VALIDATION_DATASET
from utils import load_dataset
warnings.filterwarnings('ignore')
import wandb

torch.manual_seed(47)
import random
random.seed(47)
import numpy as np
np.random.seed(47)

if torch.cuda.is_available():
 dev = "cuda:0"
else:
 dev = "mps"


device = torch.device(dev)
epochs = 10
steps=1
clustering_eval_function = lambda cluster_labels, tags: eval_massive_cluster(cluster_labels, tags, steps, epochs)

dataset_loader = load_dataset(VALIDATION_DATASET.keys())

wandb.login()
# Out:
# wandb: Currently logged in as: piodanilod (hortensias). Use `wandb login --relogin` to force relogin
# True

# %%
# !rm -r /content/data

# %%
# !pip install ultralytics

# %%
from properties import MODELS_ENUM, PREPROCESSORS, ALGORITHM, GROUPER_FUNCTIONS

DEFAULT_PARAMS = {
      "dataset": dataset_loader,
      "evaluation_function": clustering_eval_function,
      "show": True,
      "device": device
   }


AGGLOMERATIVE_PARAMS = {
            'distance_threshold':[0.5,1,2,4,5,7],
            'algorithm':["AGGLOMERATIVE"]
        }

AGGLOMERATIVE_TEMPLATE={
          'model': {
            'name': '{model_name}',
            'params': '{model_params}'
          },
          'algorithm': '{algorithm}',
          'params': { "n_clusters":None, "distance_threshold": "{distance_threshold}"},
          'grouper_function': "CLUSTERING_FUNCTION",
          'preprocessing': '{preprocessing}',
      }



SIMILARITY_PARAMS={
            "threshold":[.5,.8,.9,.99,.999,.9999,1,],
            "distance": ["euclidean","cosine"],
            'algorithm':["SIMILARITY"]
        }
SIMILARITY_TEMPLATE={
          'model': {
            'name': '{model_name}',
            'params': '{model_params}'
          },
          'algorithm': '{algorithm}',
          'params': { "threshold":'{threshold}', "distance":'{distance}' },
          'grouper_function': "CLUSTERING_FUNCTION",
          'preprocessing': '{preprocessing}',
      }


DBSCAN_PARAMS={
'algorithm':["DBSCAN"],
'eps' :[0.4,0.5,0.6,0.7],
'min_samples':[5,6,7,10,],
}
DBSCAN_TEMPLATE={
          'model': {
            'name': '{model_name}',
            'params': '{model_params}'
          },
          'algorithm': '{algorithm}',
          'params': {'eps' : '{eps}',
'min_samples':'{min_samples}'
},
          'grouper_function': "CLUSTERING_FUNCTION",
          'preprocessing': '{preprocessing}',
      }

# %%
# !mkdir /content/embeddings

# %%
#!pip install gensim

# %%
# import torch
# import gensim.downloader as api
# from gensim.models import Word2Vec
# import numpy as np

# # Cargar modelo Word2Vec preentrenado (puede cambiar según tus necesidades)
# WORD_2_VEC = api.load('word2vec-google-news-300')  # Este es un modelo grande; asegúrate de tener suficiente RAM

# #WORD_2_VEC ={}

# %%
from itertools import product
import copy
import json
import datetime


BASE_EXPERIMENTS_DEFINITIONS= [
    #  {
    #     'embeddings_params':{
    #         'preprocessing':["YOLO_BASELINE"],
    #         'model_name':['Encoder'],
    #         'model_params':[['best_rico.pt', 'autoencoderv5.pt', device]]
    #          #['best_rico.pt', 'autoencoderv5.pt', device]]
    #     },
    #   'name': "Encoder yolo mask clustering"
    # },




    #  {
    #     'embeddings_params':{
    #         'preprocessing':["BASELINE"],
    #         'model_name':['RESNET18'],
    #         'model_params':[[device]]

    #     },
    #   'name': "Pretrained Nets"
    # },

       {
        'embeddings_params':{
            'preprocessing':["YOLO_BASELINE"],
            'model_name':['YOLOMOBILE'],
            'model_params':[[device,'best_rico.pt'],[device,'best.pt'],[device,'yolov8n.pt']]

        },
      'name': "YOLO_MOBILENET"
    },

    #   {
    #     'embeddings_params':{
    #         'preprocessing':["YOLO_BASELINE"],
    #         'model_name':["YOLOV8"],
    #         'model_params':[['best_rico.pt'],['best.pt'],['yolov8n.pt']]

    #     },
    #   'name': "YOLO"
    # },





    #  {
    #     'embeddings_params':{
    #         'preprocessing':["BASELINE"],
    #         'model_name':['SIAMESE_RESNET18'],
    #         'model_params':[[device,'siameseResnetCuratedEuclidea.pt' ]]


    #         # 'model_params':[[device,'siameseResnet18Cosine.pt' ],
    #         #                 [device,'siameseResnet18EuclideanFull.pt' ]]

    #     },
    #   'name': "Siamese Resnet"
    # },




    #  {
    #     'embeddings_params':{
    #         'preprocessing':["BASELINE"],
    #         'model_name':['SIAMESE_MOBILENET'],
    #         'model_params':[
    #                         [device,'siameseMobilenetCuratedEuclidean.pt' ]]

    #     },
    #   'name': "Siamese MobileNet"
    # },
    #     {
    #     'embeddings_params':{
    #         'preprocessing':["YOLO_BASELINE"],
    #         'model_name':['SIAMESE_YOLO'],
    #         'model_params':[['best_rico.pt',device,'siameseyolouratedCosine.pt' ],
    #                         ['best_rico.pt',device,'siameseyolouratedEuclidean.pt' ]]

    #     },
    #   'name': "Siamese YOLO"
    # },


#      {
#         'embeddings_params':{
#             'preprocessing':["YOLO_BASELINE"],
#             'model_name':['PRETRAINED_IMAGE_DESCRIPTOR'],
#             'model_params':[
#                             [device, 'google/pix2struct-screen2words-base','In the context of mobile user interface, provide a label for the screen that sums up its functionality'],
#  [device, 'google/pix2struct-screen2words-large','In the context of mobile user interface, provide a label for the screen that sums up its functionality'],
#  [device, 'google/pix2struct-textcaps-base','In the context of mobile user interface, provide a label for the screen that sums up its functionality'],
#  [device, 'google/pix2struct-textcaps-large','In the context of mobile user interface, provide a label for the screen that sums up its functionality'],
#  [device, 'google/pix2struct-docvqa-large','In the context of mobile user interface, provide a label for the screen that sums up its functionality'],

#                                    [device, 'google/pix2struct-screen2words-base','is this screen a loading page or a skeleton ?'],
#  [device, 'google/pix2struct-screen2words-large','is this screen a loading page or a skeleton ?'],
#  [device, 'google/pix2struct-textcaps-base','is this screen a loading page or a skeleton ?'],
#  [device, 'google/pix2struct-textcaps-large','is this screen a loading page or a skeleton ?'],
#  [device, 'google/pix2struct-docvqa-large','is this screen a loading page or a skeleton ?'],
#                     [device, 'google/pix2struct-screen2words-base','describe the image'],
#  [device, 'google/pix2struct-screen2words-large','describe the image'],
#  [device, 'google/pix2struct-textcaps-base','describe the image'],
#  [device, 'google/pix2struct-textcaps-large','describe the image'],
#  [device, 'google/pix2struct-docvqa-large','describe the image'],
# ],
#         },
#       'name': "Pretrained Image Descriptor"
#     },

    #  {
    #     'embeddings_params':{
    #         'preprocessing':["YOLO_BASELINE"],
    #         'model_name':['PRETRAINED_IMAGE_DESCRIPTOR_DECODER'],
    #         'model_params':[
    #                     [device, 'google/pix2struct-screen2words-large','In the context of mobile user interface, provide a label for the screen that sums up its functionality',WORD_2_VEC,.85],

    #         ],
    #     },
    #   'name': "Pretrained Image Decoder"
    # },

]
def get_experiment_definitions(exps):
  exps_emb = exps['embeddings_params']
  params  = {**exps_emb, **exps['other_params']}
  config = exps['template']
  name = exps['name']


  # Función recursiva para reemplazar valores en el JSON
  def replace_values(d, key, value_to_replace):
      if isinstance(d, dict):
          for k, v in d.items():
              if isinstance(v, dict) or isinstance(v, list):
                  replace_values(v, key, value_to_replace)
              elif isinstance(v, str) and v == "{" + key + "}":
                  d[k] = value_to_replace
      elif isinstance(d, list):
          for i, item in enumerate(d):
              if isinstance(item, dict) or isinstance(item, list):
                  replace_values(item, key, value_to_replace)
              elif isinstance(item, str) and item == "{" + key + "}":
                  d[i] = value_to_replace

  # Generar todas las combinaciones de los valores en params
  combinations = list(product(*params.values()))

  configs_modified = []

  for combination in combinations:
      # Crear una copia profunda del JSON original para cada combinación
      config_modified = copy.deepcopy(config)
      params_log =  zip(params.keys(), combination)
      name_components = [name]
      embeddings_hyperparams = []
      for key, value in params_log:
          replace_values(config_modified, key, value)
          name_components.append(f"{key}={value}")
          if key in exps_emb.keys():
              embeddings_hyperparams.append(f"{key}={value}")
      config_modified['raw_name'] = name
      config_modified['name'] = ', '.join(name_components)
      config_modified['hyperparams'] = ', '.join(embeddings_hyperparams)
      configs_modified.append(config_modified)

  # Imprimir los JSON modificados para verificar
  # for config in configs_modified:
  #     print(json.dumps(config, indent=4))
  return configs_modified


def add_clustering_method(exps):
    result = []
    for exp in exps:
        aglomerative = copy.deepcopy(exp)
        aglomerative['name'] = aglomerative['name']+" Agglomerative"
        aglomerative_dict = {
            'other_params':AGGLOMERATIVE_PARAMS,
            'template':AGGLOMERATIVE_TEMPLATE,
        }

        aglomerative={**aglomerative, **aglomerative_dict}


        simalarity = copy.deepcopy(exp)
        #simalarity['name'] = simalarity['name']+" Similarity"
        simalarity_dict = {
            'other_params':SIMILARITY_PARAMS,
            'template':SIMILARITY_TEMPLATE,
            'name': simalarity['name'] + " Similarity"
        }
        simalarity={**simalarity, **simalarity_dict}

        dbscan=copy.deepcopy(exp)
        dbscan['name'] = dbscan['name']+" DBSCAN"
        dbscan_dict = {
            'other_params':DBSCAN_PARAMS,
            'template':DBSCAN_TEMPLATE,
        }
        dbscan={**dbscan, **dbscan_dict}
        result.append(aglomerative)
        result.append(simalarity)
        result.append(dbscan)
    return result


EXPERIMENTS_DEFINITIONS = add_clustering_method(BASE_EXPERIMENTS_DEFINITIONS)
EXPERIMENT_DEFINITIONS = []



for exps_definition in EXPERIMENTS_DEFINITIONS:
  EXPERIMENT_DEFINITIONS.extend(    get_experiment_definitions(exps_definition))


number_of_experiments = len(EXPERIMENT_DEFINITIONS)


i=0
start = datetime.datetime.now()
for exp_definition in EXPERIMENT_DEFINITIONS:
    i=i+1
    if i>0:
      params = DEFAULT_PARAMS.copy()
      model_definition = MODELS_ENUM[exp_definition["model"]["name"]]
      model_params = exp_definition["model"]["params"]
      model = model_definition(*model_params)
      params["model"] = model
      params["preprocessing"] = PREPROCESSORS[exp_definition["preprocessing"]]
      algorithm = ALGORITHM[exp_definition["algorithm"]](**exp_definition["params"])
      grouper_function = GROUPER_FUNCTIONS[exp_definition["grouper_function"]](algorithm)
      params["grouper_function"] = grouper_function
      params["name"] = exp_definition["name"]
      params["dataset"] = dataset_loader()
      params['hyperparams']=exp_definition["hyperparams"]
      result = experiment(**params)
      run = wandb.init(project="run-all-v1",group=exp_definition['raw_name'], entity="hortensias")
      run.log({
        "PCA_FILE":model.get_short_name(params['hyperparams']),
        "hyperparams": exp_definition['name'],
        "Precision": result.precision.mean,
        "Accuracy": result.accuracy.mean,
        "F1": result.f1.mean,
        "Recall": result.recall.mean,
        "Precision_STD": result.precision.std,
        "Accuracy_STD": result.accuracy.std,
        "F1_STD": result.f1.std,
        "Recall_STD": result.recall.std,
      })
      run.finish()

    avance = i / number_of_experiments
    diferencia = datetime.datetime.now() - start
    tiempo_restante = ((1 - avance) / avance) * diferencia.total_seconds()
    tiempo_restante = datetime.timedelta(seconds=tiempo_restante)

    horas = tiempo_restante.seconds // 3600
    minutos = (tiempo_restante.seconds % 3600) // 60
    segundos = tiempo_restante.seconds % 60

    print(f"Se han corrido {i} de {number_of_experiments} experimentos. {avance * 100:.2f} % avance, tiempo restante: {horas}h{minutos:02d}m{segundos:02d}s")
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_large-8738ca79.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_large-8738ca79.pth
# 100%|██████████| 21.1M/21.1M [00:00<00:00, 71.7MB/s]
# Generating embedding for name:  yolomobile-output.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-Airbnb.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-pedidosya.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-wikipedia.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-Alibaba.com.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-CNN_posts.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-PS_unistall.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-FIFA_home_results.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-Pinterest_view_save.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-X_twitter_comment.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-X_unfollow.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-X_follow_notification.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-meli_1.mp4.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
# Generating embedding for name:  yolomobile-chrome_post_post.mp4-0d4b2dd22bf9a5a9187d57d7b618af58e65f51fd630a44e6288e0b7355ce2f2e
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best_rico.pt'], distance_threshold=0.5, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.92, std: 0.0773986347
# Recall - Mean: 0.24, std: 0.1278508149
# F1-Score - Mean: 0.34, std: 0.1581143387
# Accuracy - Mean: 0.24, std: 0.1278508149
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_015145-g6x8no3g</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/g6x8no3g' target="_blank">stellar-snowball-2296</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/g6x8no3g' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/g6x8no3g</a>
# VBox(children=(Label(value='0.001 MB of 0.011 MB uploaded\r'), FloatProgress(value=0.10599599686711339, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.23794</td></tr><tr><td>Accuracy_STD</td><td>0.12785</td></tr><tr><td>F1</td><td>0.34319</td></tr><tr><td>F1_STD</td><td>0.15811</td></tr><tr><td>PCA_FILE</td><td>yolomobile-0d4b2dd22...</td></tr><tr><td>Precision</td><td>0.92365</td></tr><tr><td>Precision_STD</td><td>0.0774</td></tr><tr><td>Recall</td><td>0.23794</td></tr><tr><td>Recall_STD</td><td>0.12785</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stellar-snowball-2296</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/g6x8no3g' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/g6x8no3g</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_015145-g6x8no3g/logs</code>
# Se han corrido 1 de 108 experimentos. 0.93 % avance, tiempo restante: 15h06m06s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best_rico.pt'], distance_threshold=1, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.90, std: 0.1083493322
# Recall - Mean: 0.28, std: 0.1459809140
# F1-Score - Mean: 0.38, std: 0.1703224071
# Accuracy - Mean: 0.28, std: 0.1459809140
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_015159-ku14c9wh</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/ku14c9wh' target="_blank">deep-voice-2297</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/ku14c9wh' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/ku14c9wh</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.27682</td></tr><tr><td>Accuracy_STD</td><td>0.14598</td></tr><tr><td>F1</td><td>0.38331</td></tr><tr><td>F1_STD</td><td>0.17032</td></tr><tr><td>PCA_FILE</td><td>yolomobile-0d4b2dd22...</td></tr><tr><td>Precision</td><td>0.89738</td></tr><tr><td>Precision_STD</td><td>0.10835</td></tr><tr><td>Recall</td><td>0.27682</td></tr><tr><td>Recall_STD</td><td>0.14598</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">deep-voice-2297</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/ku14c9wh' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/ku14c9wh</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_015159-ku14c9wh/logs</code>
# Se han corrido 2 de 108 experimentos. 1.85 % avance, tiempo restante: 7h41m09s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best_rico.pt'], distance_threshold=2, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.87, std: 0.1208213386
# Recall - Mean: 0.33, std: 0.1533528513
# F1-Score - Mean: 0.44, std: 0.1675465554
# Accuracy - Mean: 0.33, std: 0.1533528513
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_015216-4typ4geq</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/4typ4geq' target="_blank">spring-glade-2298</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/4typ4geq' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/4typ4geq</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.32927</td></tr><tr><td>Accuracy_STD</td><td>0.15335</td></tr><tr><td>F1</td><td>0.43593</td></tr><tr><td>F1_STD</td><td>0.16755</td></tr><tr><td>PCA_FILE</td><td>yolomobile-0d4b2dd22...</td></tr><tr><td>Precision</td><td>0.86641</td></tr><tr><td>Precision_STD</td><td>0.12082</td></tr><tr><td>Recall</td><td>0.32927</td></tr><tr><td>Recall_STD</td><td>0.15335</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">spring-glade-2298</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/4typ4geq' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/4typ4geq</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_015216-4typ4geq/logs</code>
# Se han corrido 3 de 108 experimentos. 2.78 % avance, tiempo restante: 5h14m11s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best_rico.pt'], distance_threshold=4, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.85, std: 0.1015623697
# Recall - Mean: 0.37, std: 0.1569213531
# F1-Score - Mean: 0.47, std: 0.1678262556
# Accuracy - Mean: 0.37, std: 0.1569213531
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_015231-yhq0xm79</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/yhq0xm79' target="_blank">confused-pyramid-2299</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/yhq0xm79' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/yhq0xm79</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.36943</td></tr><tr><td>Accuracy_STD</td><td>0.15692</td></tr><tr><td>F1</td><td>0.46694</td></tr><tr><td>F1_STD</td><td>0.16783</td></tr><tr><td>PCA_FILE</td><td>yolomobile-0d4b2dd22...</td></tr><tr><td>Precision</td><td>0.85199</td></tr><tr><td>Precision_STD</td><td>0.10156</td></tr><tr><td>Recall</td><td>0.36943</td></tr><tr><td>Recall_STD</td><td>0.15692</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">confused-pyramid-2299</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/yhq0xm79' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/yhq0xm79</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_015231-yhq0xm79/logs</code>
# Se han corrido 4 de 108 experimentos. 3.70 % avance, tiempo restante: 4h00m05s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best_rico.pt'], distance_threshold=5, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.83, std: 0.1194599665
# Recall - Mean: 0.39, std: 0.1514770230
# F1-Score - Mean: 0.49, std: 0.1547266930
# Accuracy - Mean: 0.39, std: 0.1514770230
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_015246-xs9fuug9</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/xs9fuug9' target="_blank">efficient-monkey-2300</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/xs9fuug9' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/xs9fuug9</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.39493</td></tr><tr><td>Accuracy_STD</td><td>0.15148</td></tr><tr><td>F1</td><td>0.48984</td></tr><tr><td>F1_STD</td><td>0.15473</td></tr><tr><td>PCA_FILE</td><td>yolomobile-0d4b2dd22...</td></tr><tr><td>Precision</td><td>0.83427</td></tr><tr><td>Precision_STD</td><td>0.11946</td></tr><tr><td>Recall</td><td>0.39493</td></tr><tr><td>Recall_STD</td><td>0.15148</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">efficient-monkey-2300</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/xs9fuug9' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/xs9fuug9</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_015246-xs9fuug9/logs</code>
# Se han corrido 5 de 108 experimentos. 4.63 % avance, tiempo restante: 3h15m20s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best_rico.pt'], distance_threshold=7, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.81, std: 0.1232538917
# Recall - Mean: 0.42, std: 0.1325555282
# F1-Score - Mean: 0.52, std: 0.1351114345
# Accuracy - Mean: 0.42, std: 0.1325555282
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_015301-6k7dvbvy</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/6k7dvbvy' target="_blank">northern-hill-2301</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/6k7dvbvy' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/6k7dvbvy</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.4217</td></tr><tr><td>Accuracy_STD</td><td>0.13256</td></tr><tr><td>F1</td><td>0.51669</td></tr><tr><td>F1_STD</td><td>0.13511</td></tr><tr><td>PCA_FILE</td><td>yolomobile-0d4b2dd22...</td></tr><tr><td>Precision</td><td>0.8137</td></tr><tr><td>Precision_STD</td><td>0.12325</td></tr><tr><td>Recall</td><td>0.4217</td></tr><tr><td>Recall_STD</td><td>0.13256</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">northern-hill-2301</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/6k7dvbvy' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/6k7dvbvy</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_015301-6k7dvbvy/logs</code>
# Se han corrido 6 de 108 experimentos. 5.56 % avance, tiempo restante: 2h45m27s
# Generating embedding for name:  yolomobile-output.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-Airbnb.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-pedidosya.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-wikipedia.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-Alibaba.com.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-CNN_posts.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-PS_unistall.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-FIFA_home_results.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-Pinterest_view_save.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-X_twitter_comment.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-X_unfollow.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-X_follow_notification.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-meli_1.mp4.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
# Generating embedding for name:  yolomobile-chrome_post_post.mp4-2967185cdbba39655a876e2a18505bf1c6a84397805129d757e5c1b230530da2
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best.pt'], distance_threshold=0.5, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.93, std: 0.0711164020
# Recall - Mean: 0.24, std: 0.1260022648
# F1-Score - Mean: 0.35, std: 0.1551865838
# Accuracy - Mean: 0.24, std: 0.1260022648
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_020201-67ddj8vb</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/67ddj8vb' target="_blank">denim-wind-2302</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/67ddj8vb' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/67ddj8vb</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.23973</td></tr><tr><td>Accuracy_STD</td><td>0.126</td></tr><tr><td>F1</td><td>0.34592</td></tr><tr><td>F1_STD</td><td>0.15519</td></tr><tr><td>PCA_FILE</td><td>yolomobile-2967185cd...</td></tr><tr><td>Precision</td><td>0.93251</td></tr><tr><td>Precision_STD</td><td>0.07112</td></tr><tr><td>Recall</td><td>0.23973</td></tr><tr><td>Recall_STD</td><td>0.126</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">denim-wind-2302</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/67ddj8vb' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/67ddj8vb</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_020201-67ddj8vb/logs</code>
# Se han corrido 7 de 108 experimentos. 6.48 % avance, tiempo restante: 4h30m31s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best.pt'], distance_threshold=1, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.90, std: 0.1053163514
# Recall - Mean: 0.28, std: 0.1451307491
# F1-Score - Mean: 0.38, std: 0.1699052022
# Accuracy - Mean: 0.28, std: 0.1451307491
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_020216-z70s4ecc</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/z70s4ecc' target="_blank">silver-serenity-2303</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/z70s4ecc' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/z70s4ecc</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.27713</td></tr><tr><td>Accuracy_STD</td><td>0.14513</td></tr><tr><td>F1</td><td>0.3847</td></tr><tr><td>F1_STD</td><td>0.16991</td></tr><tr><td>PCA_FILE</td><td>yolomobile-2967185cd...</td></tr><tr><td>Precision</td><td>0.89921</td></tr><tr><td>Precision_STD</td><td>0.10532</td></tr><tr><td>Recall</td><td>0.27713</td></tr><tr><td>Recall_STD</td><td>0.14513</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">silver-serenity-2303</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/z70s4ecc' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/z70s4ecc</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_020216-z70s4ecc/logs</code>
# Se han corrido 8 de 108 experimentos. 7.41 % avance, tiempo restante: 3h57m20s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best.pt'], distance_threshold=2, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.86, std: 0.1190957710
# Recall - Mean: 0.33, std: 0.1515901575
# F1-Score - Mean: 0.43, std: 0.1659230142
# Accuracy - Mean: 0.33, std: 0.1515901575
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01111268243333446, max=1.0)…
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_020231-1uvkel5c</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/1uvkel5c' target="_blank">skilled-sky-2304</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/1uvkel5c' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/1uvkel5c</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.32794</td></tr><tr><td>Accuracy_STD</td><td>0.15159</td></tr><tr><td>F1</td><td>0.43462</td></tr><tr><td>F1_STD</td><td>0.16592</td></tr><tr><td>PCA_FILE</td><td>yolomobile-2967185cd...</td></tr><tr><td>Precision</td><td>0.86202</td></tr><tr><td>Precision_STD</td><td>0.1191</td></tr><tr><td>Recall</td><td>0.32794</td></tr><tr><td>Recall_STD</td><td>0.15159</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">skilled-sky-2304</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/1uvkel5c' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/1uvkel5c</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_020231-1uvkel5c/logs</code>
# Se han corrido 9 de 108 experimentos. 8.33 % avance, tiempo restante: 3h32m44s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best.pt'], distance_threshold=4, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.86, std: 0.0994037096
# Recall - Mean: 0.37, std: 0.1569714998
# F1-Score - Mean: 0.47, std: 0.1676189307
# Accuracy - Mean: 0.37, std: 0.1569714998
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_020253-xsnzimwm</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/xsnzimwm' target="_blank">ancient-capybara-2305</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/xsnzimwm' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/xsnzimwm</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.36952</td></tr><tr><td>Accuracy_STD</td><td>0.15697</td></tr><tr><td>F1</td><td>0.46739</td></tr><tr><td>F1_STD</td><td>0.16762</td></tr><tr><td>PCA_FILE</td><td>yolomobile-2967185cd...</td></tr><tr><td>Precision</td><td>0.85698</td></tr><tr><td>Precision_STD</td><td>0.0994</td></tr><tr><td>Recall</td><td>0.36952</td></tr><tr><td>Recall_STD</td><td>0.15697</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ancient-capybara-2305</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/xsnzimwm' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/xsnzimwm</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_020253-xsnzimwm/logs</code>
# Se han corrido 10 de 108 experimentos. 9.26 % avance, tiempo restante: 3h12m12s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best.pt'], distance_threshold=5, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.84, std: 0.1070445918
# Recall - Mean: 0.39, std: 0.1530383894
# F1-Score - Mean: 0.49, std: 0.1552959742
# Accuracy - Mean: 0.39, std: 0.1530383894
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_020309-0krmsi54</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/0krmsi54' target="_blank">blooming-cloud-2306</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/0krmsi54' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/0krmsi54</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.39226</td></tr><tr><td>Accuracy_STD</td><td>0.15304</td></tr><tr><td>F1</td><td>0.48626</td></tr><tr><td>F1_STD</td><td>0.1553</td></tr><tr><td>PCA_FILE</td><td>yolomobile-2967185cd...</td></tr><tr><td>Precision</td><td>0.83875</td></tr><tr><td>Precision_STD</td><td>0.10704</td></tr><tr><td>Recall</td><td>0.39226</td></tr><tr><td>Recall_STD</td><td>0.15304</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">blooming-cloud-2306</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/0krmsi54' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/0krmsi54</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_020309-0krmsi54/logs</code>
# Se han corrido 11 de 108 experimentos. 10.19 % avance, tiempo restante: 2h55m22s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'best.pt'], distance_threshold=7, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.81, std: 0.1252072431
# Recall - Mean: 0.42, std: 0.1319806092
# F1-Score - Mean: 0.52, std: 0.1345819846
# Accuracy - Mean: 0.42, std: 0.1319806092
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_020325-zlhopiiu</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/zlhopiiu' target="_blank">dazzling-capybara-2307</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/zlhopiiu' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/zlhopiiu</a>
# VBox(children=(Label(value='0.001 MB of 0.010 MB uploaded\r'), FloatProgress(value=0.11172261970280682, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.42131</td></tr><tr><td>Accuracy_STD</td><td>0.13198</td></tr><tr><td>F1</td><td>0.51596</td></tr><tr><td>F1_STD</td><td>0.13458</td></tr><tr><td>PCA_FILE</td><td>yolomobile-2967185cd...</td></tr><tr><td>Precision</td><td>0.81112</td></tr><tr><td>Precision_STD</td><td>0.12521</td></tr><tr><td>Recall</td><td>0.42131</td></tr><tr><td>Recall_STD</td><td>0.13198</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dazzling-capybara-2307</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/zlhopiiu' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/zlhopiiu</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_020325-zlhopiiu/logs</code>
# Se han corrido 12 de 108 experimentos. 11.11 % avance, tiempo restante: 2h42m10s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 88.7MB/s]
# Generating embedding for name:  yolomobile-output.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-Airbnb.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-pedidosya.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-wikipedia.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-Alibaba.com.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-CNN_posts.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-PS_unistall.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-FIFA_home_results.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-Pinterest_view_save.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-X_twitter_comment.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-X_unfollow.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-X_follow_notification.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-meli_1.mp4.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
# Generating embedding for name:  yolomobile-chrome_post_post.mp4-9160fe2714951fc96393cd26feaf69f4b3bb55b2abaa3ad8b204c554dbbda64d
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'yolov8n.pt'], distance_threshold=0.5, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.93, std: 0.0819200320
# Recall - Mean: 0.24, std: 0.1268131736
# F1-Score - Mean: 0.34, std: 0.1567544524
# Accuracy - Mean: 0.24, std: 0.1268131736
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_021307-fiy2w3tg</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/fiy2w3tg' target="_blank">restful-oath-2308</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/fiy2w3tg' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/fiy2w3tg</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.23562</td></tr><tr><td>Accuracy_STD</td><td>0.12681</td></tr><tr><td>F1</td><td>0.34064</td></tr><tr><td>F1_STD</td><td>0.15675</td></tr><tr><td>PCA_FILE</td><td>yolomobile-9160fe271...</td></tr><tr><td>Precision</td><td>0.92829</td></tr><tr><td>Precision_STD</td><td>0.08192</td></tr><tr><td>Recall</td><td>0.23562</td></tr><tr><td>Recall_STD</td><td>0.12681</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">restful-oath-2308</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/fiy2w3tg' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/fiy2w3tg</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_021307-fiy2w3tg/logs</code>
# Se han corrido 13 de 108 experimentos. 12.04 % avance, tiempo restante: 3h38m10s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'yolov8n.pt'], distance_threshold=1, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.90, std: 0.1044861690
# Recall - Mean: 0.28, std: 0.1459614575
# F1-Score - Mean: 0.39, std: 0.1696506048
# Accuracy - Mean: 0.28, std: 0.1459614575
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_021323-cd3nau0b</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/cd3nau0b' target="_blank">distinctive-gorge-2309</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/cd3nau0b' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/cd3nau0b</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.27944</td></tr><tr><td>Accuracy_STD</td><td>0.14596</td></tr><tr><td>F1</td><td>0.38703</td></tr><tr><td>F1_STD</td><td>0.16965</td></tr><tr><td>PCA_FILE</td><td>yolomobile-9160fe271...</td></tr><tr><td>Precision</td><td>0.90207</td></tr><tr><td>Precision_STD</td><td>0.10449</td></tr><tr><td>Recall</td><td>0.27944</td></tr><tr><td>Recall_STD</td><td>0.14596</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET Agglo...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">distinctive-gorge-2309</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/cd3nau0b' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/cd3nau0b</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_021323-cd3nau0b/logs</code>
# Se han corrido 14 de 108 experimentos. 12.96 % avance, tiempo restante: 3h22m06s
#
# Experiment name: YOLO_MOBILENET Agglomerative, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'yolov8n.pt'], distance_threshold=2, algorithm=AGGLOMERATIVE AVG
# Precision - Mean: 0.87, std: 0.1208070455
# Recall - Mean: 0.33, std: 0.1516621883
# F1-Score - Mean: 0.44, std: 0.1681040328
# Accuracy - Mean: 0.33, std: 0.1516621883
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_021339-vlnwzpn8</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/vlnwzpn8' target="_blank">neat-pine-2310</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/vlnwzpn8' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/vlnwzpn8</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
# ...
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.48413</td></tr><tr><td>Accuracy_STD</td><td>0.14442</td></tr><tr><td>F1</td><td>0.52946</td></tr><tr><td>F1_STD</td><td>0.1597</td></tr><tr><td>PCA_FILE</td><td>yolomobile-9160fe271...</td></tr><tr><td>Precision</td><td>0.71705</td></tr><tr><td>Precision_STD</td><td>0.16983</td></tr><tr><td>Recall</td><td>0.48413</td></tr><tr><td>Recall_STD</td><td>0.14442</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET DBSCA...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">worldly-gorge-2398</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/4fqh7rei' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/4fqh7rei</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_023955-4fqh7rei/logs</code>
# Se han corrido 103 de 108 experimentos. 95.37 % avance, tiempo restante: 0h02m45s
#
# Experiment name: YOLO_MOBILENET DBSCAN, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'yolov8n.pt'], algorithm=DBSCAN, eps=0.6, min_samples=10 AVG
# Precision - Mean: 0.72, std: 0.1663460306
# Recall - Mean: 0.50, std: 0.1448534567
# F1-Score - Mean: 0.53, std: 0.1588875680
# Accuracy - Mean: 0.50, std: 0.1448534567
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_024014-97s0c5d3</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/97s0c5d3' target="_blank">vital-voice-2399</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/97s0c5d3' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/97s0c5d3</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.49525</td></tr><tr><td>Accuracy_STD</td><td>0.14485</td></tr><tr><td>F1</td><td>0.53474</td></tr><tr><td>F1_STD</td><td>0.15889</td></tr><tr><td>PCA_FILE</td><td>yolomobile-9160fe271...</td></tr><tr><td>Precision</td><td>0.71833</td></tr><tr><td>Precision_STD</td><td>0.16635</td></tr><tr><td>Recall</td><td>0.49525</td></tr><tr><td>Recall_STD</td><td>0.14485</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET DBSCA...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vital-voice-2399</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/97s0c5d3' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/97s0c5d3</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_024014-97s0c5d3/logs</code>
# Se han corrido 104 de 108 experimentos. 96.30 % avance, tiempo restante: 0h02m11s
#
# Experiment name: YOLO_MOBILENET DBSCAN, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'yolov8n.pt'], algorithm=DBSCAN, eps=0.7, min_samples=5 AVG
# Precision - Mean: 0.72, std: 0.1597159145
# Recall - Mean: 0.50, std: 0.1440753285
# F1-Score - Mean: 0.55, std: 0.1578084506
# Accuracy - Mean: 0.50, std: 0.1440753285
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_024028-9d0qiezk</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/9d0qiezk' target="_blank">worldly-puddle-2400</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/9d0qiezk' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/9d0qiezk</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.49868</td></tr><tr><td>Accuracy_STD</td><td>0.14408</td></tr><tr><td>F1</td><td>0.55191</td></tr><tr><td>F1_STD</td><td>0.15781</td></tr><tr><td>PCA_FILE</td><td>yolomobile-9160fe271...</td></tr><tr><td>Precision</td><td>0.72435</td></tr><tr><td>Precision_STD</td><td>0.15972</td></tr><tr><td>Recall</td><td>0.49868</td></tr><tr><td>Recall_STD</td><td>0.14408</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET DBSCA...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">worldly-puddle-2400</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/9d0qiezk' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/9d0qiezk</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_024028-9d0qiezk/logs</code>
# Se han corrido 105 de 108 experimentos. 97.22 % avance, tiempo restante: 0h01m38s
#
# Experiment name: YOLO_MOBILENET DBSCAN, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'yolov8n.pt'], algorithm=DBSCAN, eps=0.7, min_samples=6 AVG
# Precision - Mean: 0.72, std: 0.1603595100
# Recall - Mean: 0.50, std: 0.1438847567
# F1-Score - Mean: 0.55, std: 0.1582538158
# Accuracy - Mean: 0.50, std: 0.1438847567
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_024042-xhm2kn8a</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/xhm2kn8a' target="_blank">rich-pyramid-2401</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/xhm2kn8a' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/xhm2kn8a</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.49996</td></tr><tr><td>Accuracy_STD</td><td>0.14388</td></tr><tr><td>F1</td><td>0.55205</td></tr><tr><td>F1_STD</td><td>0.15825</td></tr><tr><td>PCA_FILE</td><td>yolomobile-9160fe271...</td></tr><tr><td>Precision</td><td>0.72375</td></tr><tr><td>Precision_STD</td><td>0.16036</td></tr><tr><td>Recall</td><td>0.49996</td></tr><tr><td>Recall_STD</td><td>0.14388</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET DBSCA...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rich-pyramid-2401</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/xhm2kn8a' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/xhm2kn8a</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_024042-xhm2kn8a/logs</code>
# Se han corrido 106 de 108 experimentos. 98.15 % avance, tiempo restante: 0h01m05s
#
# Experiment name: YOLO_MOBILENET DBSCAN, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'yolov8n.pt'], algorithm=DBSCAN, eps=0.7, min_samples=7 AVG
# Precision - Mean: 0.72, std: 0.1617966334
# Recall - Mean: 0.50, std: 0.1445247917
# F1-Score - Mean: 0.55, std: 0.1596631056
# Accuracy - Mean: 0.50, std: 0.1445247917
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_024057-3nt926aj</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/3nt926aj' target="_blank">warm-pine-2402</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/3nt926aj' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/3nt926aj</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.50256</td></tr><tr><td>Accuracy_STD</td><td>0.14452</td></tr><tr><td>F1</td><td>0.5533</td></tr><tr><td>F1_STD</td><td>0.15966</td></tr><tr><td>PCA_FILE</td><td>yolomobile-9160fe271...</td></tr><tr><td>Precision</td><td>0.72378</td></tr><tr><td>Precision_STD</td><td>0.1618</td></tr><tr><td>Recall</td><td>0.50256</td></tr><tr><td>Recall_STD</td><td>0.14452</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET DBSCA...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">warm-pine-2402</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/3nt926aj' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/3nt926aj</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_024057-3nt926aj/logs</code>
# Se han corrido 107 de 108 experimentos. 99.07 % avance, tiempo restante: 0h00m32s
#
# Experiment name: YOLO_MOBILENET DBSCAN, preprocessing=YOLO_BASELINE, model_name=YOLOMOBILE, model_params=[device(type='cuda', index=0), 'yolov8n.pt'], algorithm=DBSCAN, eps=0.7, min_samples=10 AVG
# Precision - Mean: 0.73, std: 0.1594191080
# Recall - Mean: 0.51, std: 0.1447251688
# F1-Score - Mean: 0.56, std: 0.1601676977
# Accuracy - Mean: 0.51, std: 0.1447251688
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240310_024113-xhck9q1q</code>
# Syncing run <strong><a href='https://wandb.ai/hortensias/run-all-v1/runs/xhck9q1q' target="_blank">fearless-spaceship-2403</a></strong> to <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hortensias/run-all-v1' target="_blank">https://wandb.ai/hortensias/run-all-v1</a>
#  View run at <a href='https://wandb.ai/hortensias/run-all-v1/runs/xhck9q1q' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/xhck9q1q</a>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>Accuracy_STD</td><td>▁</td></tr><tr><td>F1</td><td>▁</td></tr><tr><td>F1_STD</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>Precision_STD</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Recall_STD</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.51413</td></tr><tr><td>Accuracy_STD</td><td>0.14473</td></tr><tr><td>F1</td><td>0.55977</td></tr><tr><td>F1_STD</td><td>0.16017</td></tr><tr><td>PCA_FILE</td><td>yolomobile-9160fe271...</td></tr><tr><td>Precision</td><td>0.72643</td></tr><tr><td>Precision_STD</td><td>0.15942</td></tr><tr><td>Recall</td><td>0.51413</td></tr><tr><td>Recall_STD</td><td>0.14473</td></tr><tr><td>hyperparams</td><td>YOLO_MOBILENET DBSCA...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fearless-spaceship-2403</strong> at: <a href='https://wandb.ai/hortensias/run-all-v1/runs/xhck9q1q' target="_blank">https://wandb.ai/hortensias/run-all-v1/runs/xhck9q1q</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240310_024113-xhck9q1q/logs</code>
# Se han corrido 108 de 108 experimentos. 100.00 % avance, tiempo restante: 0h00m00s

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#VALIDATION_DATASET={"Alibaba.com.mp4": [[1, 31, "NONE", ""], [32, 149, "Home", ""], [150, 202, "Lists of items", ""], [203, 789, "Product details", ""], [790, 906, "Product item", ""], [907, 1043, "Product details", ""], [1044, 1149, "Cart screen confirmation", ""], [1150, 1200, "Cart Screen", ""], [1201, 1225, "Product information", ""], [1226, 1292, "List of items", ""], [1293, 1374, "Home", ""], [1375, 1427, "Cart screen", ""]], "chrome_post_post.mp4": [[1, 34, "Home", ""], [35, 131, "search menu", ""], [132, 550, "list of posts", ""], [551, 573, "Cookies settings", ""], [574, 789, "Post information", ""], [790, 1003, "List of Posts", ""], [1004, 1238, "Post 2", ""], [1239, 1239, "NONE", ""]]}

# %%
import shutil

# Define el nombre del archivo ZIP que deseas crear (sin la extensión .zip)
archivo_zip = 'embeddings_mas_chicoaxx'

# Define la carpeta que quieres comprimir
carpeta_a_comprimir = '/content/embeddings_mas_chicoaxx'

# Crea el archivo ZIP
shutil.make_archive(archivo_zip, 'zip', carpeta_a_comprimir)
# Out:
# '/content/embeddings_mas_chicoaxx.zip'

# %%
# !cp embeddings_mas_chicoaxx.zip /content/drive/MyDrive/embeddings_mas_chicoxx.zip
# Out:
# cp: cannot create regular file '/content/drive/MyDrive/embeddings_mas_chicoxx.zip': No such file or directory

# %%
# from google.colab import files

# # Reemplaza 'nombre_de_tu_archivo.ext' con el nombre real de tu archivo
# files.download('/content/embeddings_8.zip')

# %%
# import requests
# from PIL import Image
# from transformers import Pix2StructForConditionalGeneration, Pix2StructProcessor
# import datetime
# import torch


# model = Pix2StructForConditionalGeneration.from_pretrained("google/pix2struct-screen2words-base").to(device)
# processor = Pix2StructProcessor.from_pretrained("google/pix2struct-screen2words-base")
# image = Image.open('Captura de pantalla 2024-02-24 a la(s) 21.42.44.png')

# start = datetime.datetime.now()
# for _ in range(1000):
#   # image only
#   inputs = processor(images=image, text="is this screen a loading page or a skeleton ?",return_tensors="pt").to(device)
#   print(inputs.flattened_patches.shape)

#   predictions = model.generate(**inputs)
#   print(processor.decode(predictions[0], skip_special_tokens=True))
# print(datetime.datetime.now() - start)
